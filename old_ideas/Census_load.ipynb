# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
#load census data
#https://www2.census.gov/programs-surveys/acs/tech_docs/pums/data_dict/PUMSDataDict13.txt
filename='../../Data/Census/csv_hus1014/ss14husa.csv'
# filename='../../Data/Census/csv_hus0509/ss09husa.csv'

with open(filename,'r') as f:
    reader=csv.reader(f)
    names=reader.next()
    for id_,item in enumerate(names):
        print '%i, %s' %(id_, item)
    grnt_id=[id_ for id_,item in enumerate(names) if item=='GRNTP']
    puma_id=[id_ for id_,item in enumerate(names) if item=='PUMA'][0]
    print puma_id
    pumas=[]
    for i in range(1000):
        line=reader.next()
        pumas.append(int(line[puma_id]))
    print type(pumas[0])
    plt.hist(np.asarray(pumas),50)
    plt.show()
# Out:
# 0, serialno
# 1, RT
# 2, DIVISION
# 3, PUMA
# 4, REGION
# 5, ST
# 6, ADJHSG
# 7, ADJINC
# 8, WGTP
# 9, NP
# 10, TYPE
# 11, ACR
# 12, AGS
# 13, BDS
# 14, BLD
# 15, BUS
# 16, CONP
# 17, ELEP
# 18, FS
# 19, FULP
# 20, GASP
# 21, HFL
# 22, INSP
# 23, MHP
# 24, MRGI
# 25, MRGP
# 26, MRGT
# 27, MRGX
# 28, RMS
# 29, RNTM
# 30, RNTP
# 31, SMP
# 32, TEL
# 33, TEN
# 34, VACS
# 35, VAL
# 36, VEH
# 37, WATP
# 38, YBL
# 39, FES
# 40, FINCP
# 41, FPARC
# 42, GRNTP
# 43, GRPIP
# 44, HHL
# 45, HHT
# 46, HINCP
# 47, HUGCL
# 48, HUPAC
# 49, HUPAOC
# 50, HUPARC
# 51, KIT
# 52, LNGI
# 53, MV
# 54, NOC
# 55, NPF
# 56, NPP
# 57, NR
# 58, NRC
# 59, OCPIP
# 60, PARTNER
# 61, PLM
# 62, PSF
# 63, R18
# 64, R60
# 65, R65
# 66, RESMODE
# 67, SMOCP
# 68, SMX
# 69, SRNT
# 70, SVAL
# 71, TAXP
# 72, WIF
# 73, WKEXREL
# 74, WORKSTAT
# 75, FACRP
# 76, FAGSP
# 77, FBDSP
# 78, FBLDP
# 79, FBUSP
# 80, FCONP
# 81, FELEP
# 82, FFSP
# 83, FFULP
# 84, FGASP
# 85, FHFLP
# 86, FINSP
# 87, FKITP
# 88, FMHP
# 89, FMRGIP
# ...

# %%
#load census data
#https://www2.census.gov/programs-surveys/acs/tech_docs/pums/data_dict/PUMSDataDict13.txt

filename=['../../Data/Census/CB/CB1400CZ11.dat',
          '../../Data/Census/CB/CB1300CZ11.dat',
          '../../Data/Census/CB/CB1200CZ11.dat',
          '../../Data/Census/CB/CB1100CZ11.dat',
          '../../Data/Census/CB/CB1000CZ2.dat',
          '../../Data/Census/CB/cb0900cz1.dat',
          '../../Data/Census/CB/CB0800CZ1.DAT',
          '../../Data/Census/CB/CB0700CZ1.dat',
          '../../Data/Census/CB/cb0600cz1.dat',
          '../../Data/Census/CB/cb0500cz1.dat',
          '../../Data/Census/CB/cb0400cz1.dat']
with open(filename[0],'r') as f:
#     for i in range(100):
#         print f.readline()
    df=pd.read_csv(f,header=0,delimiter='|')
print df.head()
# print df
# Out:
#    ST  ZIPCODE          GEO_ID                   GEO_TTL  FOOTID_GEO  \
# 0   1    35004  8610000US35004           35004(MOODY,AL)         NaN
# 1   1    35005  8610000US35005      35005(ADAMSVILLE,AL)         NaN
# 2   1    35006  8610000US35006           35006(ADGER,AL)         NaN
# 3   1    35007  8610000US35007       35007(ALABASTER,AL)         NaN
# 4   1    35010  8610000US35010  35010(ALEXANDER CITY,AL)         NaN
#
#    NAICS2012          NAICS2012_TTL  FOOTID_NAICS  YEAR  ESTAB     ...      \
# 0          0  Total for all sectors           NaN  2014    177     ...
# 1          0  Total for all sectors           NaN  2014     81     ...
# 2          0  Total for all sectors           NaN  2014     18     ...
# 3          0  Total for all sectors           NaN  2014    615     ...
# 4          0  Total for all sectors           NaN  2014    440     ...
#
#    EMP_N  EMP_N_F PAYQTR1  PAYQTR1_F PAYQTR1_N  PAYQTR1_N_F  PAYANN  PAYANN_F  \
# ...

# %%
#develop features
#trends in real estate data

# %%
#distance from center zip code

# %%
#apply algorithms
