# %%
import pickle
import json
import os
import googlemaps
from datetime import datetime

gmaps = googlemaps.Client(key='AIzaSyDTLABfemojSm9rxvt8joDFgQzS9-mKiI8')

# Geocoding an address

# %%
filenames=os.listdir('../../Data/Trulia/pickfiles')
del filenames[0]
print filenames
# Out:
# ['ArizonaPhoenix.pickle', 'ArizonaTucson.pickle', 'CaliforniaBalance of Los Angeles County.pickle', 'CaliforniaLos Angeles.pickle', 'CaliforniaSan Diego.pickle', 'CaliforniaSan Francisco.pickle', 'CaliforniaSan Jose.pickle', 'ColoradoDenver.pickle', 'District of ColumbiaWashington.pickle', 'FloridaJacksonville.pickle', 'IllinoisChicago.pickle', 'IndianaIndianapolis.pickle', 'MarylandBaltimore.pickle', 'MassachusettsBoston.pickle', 'MichiganDetroit.pickle', 'NevadaLas Vegas.pickle', 'New MexicoAlbuquerque.pickle', 'New YorkNew York.pickle', 'North CarolinaCharlotte.pickle', 'OhioColumbus.pickle', 'OklahomaOklahoma City.pickle', 'OregonPortland.pickle', 'PennsylvaniaPhiladelphia.pickle', 'TennesseeMemphis.pickle', 'TexasAustin.pickle', 'TexasDallas.pickle', 'TexasEl Paso.pickle', 'TexasFort Worth.pickle', 'TexasHouston.pickle', 'TexasSan Antonio.pickle', 'WashingtonSeattle.pickle', 'WisconsinMilwaukee.pickle']

# %%
filenames[24:]
# Out:
# ['TexasAustin.pickle',
#  'TexasDallas.pickle',
#  'TexasEl Paso.pickle',
#  'TexasFort Worth.pickle',
#  'TexasHouston.pickle',
#  'TexasSan Antonio.pickle',
#  'WashingtonSeattle.pickle',
#  'WisconsinMilwaukee.pickle']

# %%
for filename in filenames[24:]:
    if filename[0]=='.':
        continue
    
    with open('../../Data/Trulia/pickfiles/' + filename,'r') as pf:
        city, state, data=pickle.load(pf)
    citydict=[]
    print city
    with open('../../Data/Trulia/jsonfiles/' + city + state + '.json','w') as jf:
        for id_, nh in enumerate(data):
            print id_
            if not nh['listingStats']:
                continue
            nhl=nh['location']
            index   =int(nhl['neighborhoodId'])
            name  =nhl['neighborhoodName']
            city  =nhl['city']
            state =nhl['state']
            print str(id_) + ', ' + str(index)
            geocode_result = []
            avglistprice=[]
            medlistprice=[]
            numprops=[]
            time=[]
            try:
                geocode_result = json.dumps(gmaps.geocode(name + ', ' + city + ', ' + state))
                for item in nh['listingStats']['listingStat']:

                    date=item['weekEndingDate']
                    if isinstance(item['listingPrice']['subcategory'], list):
                        cur=item['listingPrice']['subcategory'][0]
                    else:
                        cur=item['listingPrice']['subcategory']
                    time.append(str(date))
                    numprops.append(int(cur['numberOfProperties']))
                    medlistprice.append(int(cur['medianListingPrice']))
                    avglistprice.append(int(cur['averageListingPrice']))
            #         print '%s %8s, 10%s, 10%s' %(date, cur['numberOfProperties'],cur['medianListingPrice'], cur['averageListingPrice'])
            except:
                continue
            newcur={"id_":index, "name":name, "city":city, "state":state, "geocode":geocode_result, 
                    "time":time, "avgTS":avglistprice, "medTS":medlistprice}
#             citydict.append(json.dump(newcur))
            jf.write(json.dumps(newcur,separators=(',', ':')) +'\n')

# %%
geocode_result = json.dumps(gmaps.geocode(name + ', ' + city + ', ' + state))

# %%
geocode_result
# Out:
# '[{"geometry": {"location_type": "APPROXIMATE", "bounds": {"northeast": {"lat": 42.356983, "lng": -71.07028989999999}, "southwest": {"lat": 42.341597, "lng": -71.0932962}}, "viewport": {"northeast": {"lat": 42.356983, "lng": -71.07028989999999}, "southwest": {"lat": 42.341597, "lng": -71.0932962}}, "location": {"lat": 42.35026480000001, "lng": -71.0809757}}, "address_components": [{"long_name": "Back Bay", "types": ["neighborhood", "political"], "short_name": "Back Bay"}, {"long_name": "Boston", "types": ["locality", "political"], "short_name": "Boston"}, {"long_name": "Suffolk County", "types": ["administrative_area_level_2", "political"], "short_name": "Suffolk County"}, {"long_name": "Massachusetts", "types": ["administrative_area_level_1", "political"], "short_name": "MA"}, {"long_name": "United States", "types": ["country", "political"], "short_name": "US"}], "place_id": "ChIJsfUV-A5644kRxFubWZLMo7w", "formatted_address": "Back Bay, Boston, MA, USA", "types": ["neighborhood", "p
# ...

# %%
with open('../../Data/Trulia/jsonfiles/' + city + state + '.json','w') as jf:
    for id_, nh in enumerate(data):
        if not nh['listingStats']:
            continue
        nhl=nh['location']
        index   =int(nhl['neighborhoodId'])
        name  =nhl['neighborhoodName']
        city  =nhl['city']
        state =nhl['state']
        lat   =-999
        lng   =-999

        avglistprice=[]
        medlistprice=[]
        numprops=[]
        time=[]
        try:
            for item in nh['listingStats']['listingStat']:

                date=item['weekEndingDate']
                if isinstance(item['listingPrice']['subcategory'], list):
                    cur=item['listingPrice']['subcategory'][0]
                else:
                    cur=item['listingPrice']['subcategory']
                time.append(str(date))
                numprops.append(int(cur['numberOfProperties']))
                medlistprice.append(int(cur['medianListingPrice']))
                avglistprice.append(int(cur['averageListingPrice']))
        #         print '%s %8s, 10%s, 10%s' %(date, cur['numberOfProperties'],cur['medianListingPrice'], cur['averageListingPrice'])
        except:
            continue
        newcur={"id_":index, "name":name, "city":city, "state":state, "lat":lat, "lng":lng, 
                "time":time, "avgTS":avglistprice, "medTS":medlistprice}
    #             citydict.append(json.dump(newcur))
        jf.write(json.dumps(newcur,separators=(',', ':')) +'\n')

# %%
# for id_, item in enumerate(data):
item
# Out:
# u'weekEndingDate'

# %%
# for item in data[0]['listingStats']['listingStat']:
#     print item['weekEndingDate'] + ': ' + item['subcategory'][0]

print data[2]['location']
citydict=[]
for id_, nh in enumerate(data):
    if not nh['listingStats']:
        continue
    nhl=nh['location']
    index   =int(nhl['neighborhoodId'])
    name  =nhl['neighborhoodName']
    city  =nhl['city']
    state =nhl['state']
    lat   =-999
    lng   =-999
    
    avglistprice=[]
    medlistprice=[]
    numprops=[]
    time=[]
    try:
        for item in nh['listingStats']['listingStat']:

            date=item['weekEndingDate']
            if isinstance(item['listingPrice']['subcategory'], list):
                cur=item['listingPrice']['subcategory'][0]
            else:
                cur=item['listingPrice']['subcategory']
            time.append(str(date))
            numprops.append(int(cur['numberOfProperties']))
            medlistprice.append(int(cur['medianListingPrice']))
            avglistprice.append(int(cur['averageListingPrice']))
    #         print '%s %8s, 10%s, 10%s' %(date, cur['numberOfProperties'],cur['medianListingPrice'], cur['averageListingPrice'])
    except:
        continue
    newcur={"id_":index, "name":name, "city":city, "state":state, "lat":lat, "lng":lng, 
            "time":time, "avgTS":avglistprice, "medTS":medlistprice}
    citydict.append(newcur)
# Out:
# OrderedDict([(u'neighborhoodId', u'327'), (u'neighborhoodName', u'Alvemon Heights'), (u'city', u'Tucson'), (u'state', u'AZ'), (u'searchResultsURL', u'http://www.trulia.com/AZ/Tucson,327,Alvemon_Heights/'), (u'neighborhoodGuideURL', u'http://www.trulia.com/real_estate/Alvemon_Heights-Tucson/327/'), (u'heatMapURL', u'http://www.trulia.com/home_prices/Arizona/Tucson-heat_map/')])

# %%
print nhl
# Out:
# OrderedDict([(u'neighborhoodId', u'18633'), (u'neighborhoodName', u'Acaso'), (u'city', u'Tucson'), (u'state', u'AZ'), (u'searchResultsURL', u'http://www.trulia.com/AZ/Tucson,18633,Acaso/'), (u'neighborhoodGuideURL', u'http://www.trulia.com/real_estate/Acaso-Tucson/18633/'), (u'heatMapURL', u'http://www.trulia.com/home_prices/Arizona/Tucson-heat_map/')])

# %%
trash={"hello":[1],"goodbye":[1,2,3,4,5]}

# %%
# Out:
# [{'medTS': [184900, 184900, 180614, 161007, 170971, 174186, 173479, 162786, 149650, 94500, 91500, 91000, 91500, 89500, 87500, 84917, 86071, 75171, 64843, 70733, 86983, 84900, 91983, 69417, 75000, 62131, 62450, 86907, 69050, 115000, 110921, 111742, 120143, 125714, 117121, 118000, 118000, 113986, 119857, 116429, 107470, 94593, 74950, 77079, 87400, 82400, 86686, 93558, 94700, 92300, 90700, 102975, 111875, 111250, 111250, 111250, 111250, 111607, 112143, 114986, 110893, 112500, 116229, 118917, 119950, 118133, 113857, 106372, 106080, 106080, 106920, 109720, 108850, 87417, 87540, 93125, 93250, 94354, 93850, 93600, 94400, 95979, 103529, 108875, 104857, 104000, 106786, 107500, 107500, 105833, 106071, 108750, 109881, 113300, 108179, 103500, 94736, 94630, 98813, 91507, 89760, 93503, 94251, 89190, 87200, 81700, 79464, 75750, 74821, 69494, 69993, 63000, 63000, 70607, 80629, 79707, 65336, 68450, 65907, 73900, 71871, 69083, 69550, 70614, 77757, 84900, 84900, 84493, 83471, 84214, 84557, 84043, 90729
# ...

# %%
data[0]['listingStats']['listingStat']
# Out:
# [OrderedDict([(u'weekEndingDate', u'2009-07-04'),
#               (u'listingPrice',
#                OrderedDict([(u'subcategory',
#                              [OrderedDict([(u'type', u'All Properties'),
#                                            (u'numberOfProperties', u'17'),
#                                            (u'medianListingPrice', u'184900'),
#                                            (u'averageListingPrice',
#                                             u'158062')]),
#                               OrderedDict([(u'type', u'2 Bedroom Properties'),
#                                            (u'numberOfProperties', u'1'),
#                                            (u'medianListingPrice', u'95900'),
#                                            (u'averageListingPrice',
#                                             u'95900')]),
#                               OrderedDict([(u'type', u'3 Bedroom Properties'),
# ...

# %%
myjson=[{'item1':[1,2,3,4,5], 'item2':['a','b','c']},{'item1':[10,11,12,13,14,15],'item2':['z','y']}]
with open('output.json', 'w') as f:
    json.dump(myjson,f)
