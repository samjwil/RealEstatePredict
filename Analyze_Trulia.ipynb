# %%
import numpy as np
import json
import matplotlib.pyplot as plt
from matplotlib.dates import DayLocator, HourLocator, DateFormatter, drange
import os
import pandas as pd
from datetime import datetime
from dateutil.relativedelta import relativedelta
from sklearn import linear_model, metrics
from sklearn.linear_model import LinearRegression, LogisticRegression
import trulia.location
import trulia.stats
import pickle

import googlemaps
from datetime import datetime

gmaps = googlemaps.Client(key='AIzaSyBt-zW1COAmFDk9gSI3X3q8-bDb9Fvp5Nk')

# %%
filenames=os.listdir('../../Data/Trulia/json_old')
del filenames[0]

# %%
TRULIA_KEY = 'f34yhzddf3kuth6b895ycnz8'
# neighborhoods = trulia.location.LocationInfo(TRULIA_KEY).get_neighborhoods_in_city('Los Angeles', 'CA')
neighborhood_stats = trulia.stats.TruliaStats(TRULIA_KEY).get_neighborhood_stats(neighborhood_id=7183, start_date='2014-01-01', end_date='2014-01-31')

# %%
neighborhoods
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-233108d45bf5> in <module>()
# ----> 1 neighborhoods
#       2
#       3
#
# NameError: name 'neighborhoods' is not defined

# %%
for filename in filenames:
    print filename
    with open('../../Data/Trulia/json_old/' + filename, 'r') as fr:
        with open('../../Data/Trulia/jsonfiles_wgeo/' + filename, 'w') as jf:
            for id_, line in enumerate(fr):
                nowJSON=json.loads(line)
                id_=nowJSON['id_']
                city=nowJSON['city']
                name=nowJSON['name']
                state=nowJSON['state']

                del nowJSON['lat']
                del nowJSON['lng']
                try:
                    geocode_result = json.dumps(gmaps.geocode(str(name) + ', ' + str(city) + ', ' + str(state)))
                    nowJSON['geo']=geocode_result
                except:
                    nowJSON['geo']=[]
#                 print json.dumps(nowJSON,separators=(',', ':')) +'\n'
#                 print stop
                jf.write(json.dumps(nowJSON,separators=(',', ':')) +'\n')
                print id_
# Out:
# AlbuquerqueNew Mexico.json
# 4646
# 4647
# 4648
# 4649
# 4650
# 4651
# 4652
# 4653
# 4654
# 4657
# 4658
# 4659
# 4660
# 4661
# 4662
# 4663
# 4664
# 4665
# 4666
# 4667
# 4668
# 4669
# 4670
# 4671
# 4672
# 4673
# 4674
# 4675
# 4676
# 4677
# 4678
# 4679
# 4680
# 4681
# 4682
# 4683
# 4684
# 4685
# 4686
# 4688
# 4689
# 4690
# 4692
# 4693
# 4694
# 4695
# 4696
# 4697
# 4698
# 4699
# 4700
# 4701
# 4702
# 4703
# 4705
# 4706
# 4707
# 4708
# 4709
# 4710
# 4711
# 4712
# 4713
# 4714
# 4715
# 4716
# 4717
# 4718
# 4719
# 4720
# 4721
# 4722
# 4723
# 4724
# 4725
# 4726
# 4727
# 4729
# 4730
# 4731
# 4734
# 4735
# 4736
# 4738
# 4739
# 4740
# 4741
# 4742
# 4744
# 4745
# 4746
# 4747
# 4748
# 4749
# 4750
# 4752
# 4753
# 4754
# 4756
# 4757
# 4758
# 4759
# 4760
# 4761
# 4762
# 4763
# 4764
# 4765
# 4766
# 4767
# 4768
# 4769
# 4770
# 4771
# 4772
# 4773
# 4774
# 4775
# 4776
# 4777
# 4778
# 4779
# 4780
# 4781
# 4782
# 4783
# 4784
# 4785
# 4786
# 4787
# 4788
# 4789
# 4790
# 4791
# 4792
# 4793
# 4794
# 4795
# ...

# %%
city='Albuquerque'
state='New Mexico'

gmaps.geocode(str(city) + ', ' + str(state))
# Out:
# [{u'address_components': [{u'long_name': u'Albuquerque',
#     u'short_name': u'Albuquerque',
#     u'types': [u'locality', u'political']},
#    {u'long_name': u'Bernalillo County',
#     u'short_name': u'Bernalillo County',
#     u'types': [u'administrative_area_level_2', u'political']},
#    {u'long_name': u'New Mexico',
#     u'short_name': u'NM',
#     u'types': [u'administrative_area_level_1', u'political']},
#    {u'long_name': u'United States',
#     u'short_name': u'US',
#     u'types': [u'country', u'political']}],
#   u'formatted_address': u'Albuquerque, NM, USA',
#   u'geometry': {u'bounds': {u'northeast': {u'lat': 35.218054,
#      u'lng': -106.471163},
#     u'southwest': {u'lat': 34.946766, u'lng': -106.8817961}},
#    u'location': {u'lat': 35.0853336, u'lng': -106.6055534},
#    u'location_type': u'APPROXIMATE',
#    u'viewport': {u'northeast': {u'lat': 35.218054, u'lng': -106.471163},
#     u'southwest': {u'lat': 34.946766, u'lng': -106.8817961}}},
# ...

# %%
# nowJSON

# %%
for filename in filenames:
    print filename
    fig, ax=plt.subplots(nrows=1,ncols=1)
    with open('../../Data/Trulia/json_old/' + filename, 'r') as f:
        for id_, line in enumerate(f):
            if id_%4!=0:
                continue
            nowJSON=json.loads(line)
            TS=nowJSON['medTS']
            date=[datetime.strptime(item, '%Y-%m-%d') for item in nowJSON['time']]
            ax.plot(date,TS,linestyle='None',marker='.')
    ax.xaxis.set_major_formatter(DateFormatter('%Y'))
    ax.set_ylim([0,5000000])
    plt.show()
#     print stop
# Out:
# AlbuquerqueNew Mexico.json
# AustinTexas.json
# Balance of Los Angeles CountyCalifornia.json
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     305                 pass
#     306             else:
# --> 307                 return printer(obj)
#     308             # Finally look for special method names
#     309             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     225
#     226     if 'png' in formats:
# --> 227         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     228     if 'retina' in formats or 'png2x' in formats:
#     229         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ...

# %%
#assumption 1:
#Markets between 2012 to 2014 will predict the prices in 2016
plt.close('all')
for filename in filenames:
    print filename
    fig, ax=plt.subplots(nrows=1,ncols=1)
    with open('../../Data/Trulia/jsonfiles/' + filename, 'r') as f:
        for id_, line in enumerate(f):
            if id_%4!=0:
                continue
            nowJSON=json.loads(line)
            medTS=nowJSON['medTS']
            avgTS=nowJSON['avgTS']
            date=[datetime.strptime(item, '%Y-%m-%d') for item in nowJSON['time']]
            ax.plot(date,np.array(avgTS) - np.array(medTS),linestyle='None',marker='.')
#     ax.xaxis.set_major_formatter(DateFormatter('%Y'))
#     ax.set_ylim([0,5000000])
    plt.show()
#     print stop
# Out:
# AlbuquerqueNew Mexico.json
# AustinTexas.json
# Balance of Los Angeles CountyCalifornia.json
# BaltimoreMaryland.json
# BaltimoreMD.json
# BostonMassachusetts.json
# CharlotteNorth Carolina.json
# ChicagoIllinois.json
# ColumbusOhio.json
# DallasTexas.json
# DenverColorado.json
# DetroitMichigan.json
# El PasoTexas.json
# Fort WorthTexas.json
# HoustonTexas.json
# IndianapolisIndiana.json
# JacksonvilleFlorida.json
# Las VegasNevada.json
# Los AngelesCalifornia.json
# MemphisTennessee.json
# MilwaukeeWisconsin.json
# New YorkNew York.json
# Oklahoma CityOklahoma.json
# PhiladelphiaPennsylvania.json
# PortlandOregon.json
# San AntonioTexas.json
# San DiegoCalifornia.json
# San FranciscoCalifornia.json
# San JoseCalifornia.json
# SeattleWashington.json
# TucsonArizona.json
# WashingtonDistrict of Columbia.json

# %%
#assumption 1:
#Markets between 2012 to 2014 will predict the prices in 2016
plt.close('all')
for filename in filenames:
    print filename
    fig, ax=plt.subplots(nrows=1,ncols=1)
    with open('../../Data/Trulia/jsonfiles/' + filename, 'r') as f:
        for id_, line in enumerate(f):
            if id_%4!=0:
                continue
            nowJSON=json.loads(line)
            medTS=np.array(nowJSON['medTS'])
            avgTS=np.array(nowJSON['avgTS'])
            date=[datetime.strptime(item, '%Y-%m-%d') for item in nowJSON['time']]
            ax.plot(date,avgTS - medTS,linestyle='None',marker='.')
    
    plt.show()

# %%
dEN=datetime.strptime('2014-01-01', '%Y-%m-%d')
dST=dEN-24
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-4563acc38f58> in <module>()
#       1 dEN=datetime.strptime('2014-01-01', '%Y-%m-%d')
# ----> 2 dST=dEN-24
#
# TypeError: unsupported operand type(s) for -: 'datetime.datetime' and 'int'

# %%
def date_linear(date,TS):
    dPR=datetime.strptime('2016-01-01', '%Y-%m-%d')
    dEN=dPR-relativedelta(months=6)
    dST=dPR-relativedelta(months=12)
    #find indices of each date above
    
    
    try:
        idPR=next(id_ for id_, obj in enumerate(date) if obj>dPR)
        idEN=next(id_ for id_, obj in enumerate(date) if obj>dEN)
        idST=next(id_ for id_, obj in enumerate(date) if obj>dST)
        #convert to seconds
        datesec=[(item-datetime(1970,1,1)).total_seconds() for item in date]

        #find linear fit for dEN to dST
        regr = linear_model.LogisticRegression()
#         regr = linear_model.LinearRegression()
        
        #regr.fit_intercept = False
        x_train=np.array(datesec[idST:idEN]).reshape(-1,1)
        y_train=np.array(TS[idST:idEN])

#         y_train= y_train.reshape(y_train.size,1)
#         x_train=x_train.reshape(y_train.size,1)

        regr.fit(x_train, y_train)
    
        predicted=regr.predict(datesec[idPR])
        actual=np.mean(TS[idPR:])
#         coefs=
    except:
        predicted=np.NAN
        actual=np.NAN
        coefs=np.NAN
    return predicted, actual


#     regr.coef
#     print('Coefficients: ', regr.coef_)
#     print('Variance score training set: %.2f' % regr.score(x_train, y_train))
#     predicted_y_train_z = regr.predict(x_train_z)
#     np.polyfit(datesec[idST,idEN],TS[idST,idEN], 1, full=True, cov=True)
    
    #predict

# %%
dPR=datetime.strptime('2016-01-01', '%Y-%m-%d')
dEN=dPR-relativedelta(years=2)
dST=dPR-relativedelta(years=4)
#find indices of each date above
# [id_ for id_, obj in enumerate(date) if obj>dEN]

# datesec=[(item-datetime(1970,1,1)).total_seconds() for item in date]
# print datesec

# %%
for filename in filenames:
    print filename
    fig, ax=plt.subplots(nrows=1,ncols=1)
    with open('../../Data/Trulia/jsonfiles_wgeo/' + filename, 'r') as f:
        pred=[]
        actu=[]
        for id_, line in enumerate(f):
            if id_%4!=0:
                continue
            nowJSON=json.loads(line)
            medTS=np.array(nowJSON['medTS'])
            avgTS=np.array(nowJSON['avgTS'])
            
#             np.append(TSm,avgTS)
            date=[datetime.strptime(item, '%Y-%m-%d') for item in nowJSON['time']]
            p, a= date_linear(date,avgTS)
            pred.append(p)
            actu.append(a)
        ax.plot(actu,pred,linestyle='None',marker='.')
#         ax.set_xlim([0.5e7,1.5e7])
        plt.show()
#         print stop
    
#     print stop
# Out:
# AlbuquerqueNew Mexico.json
# AustinTexas.json
# Balance of Los Angeles CountyCalifornia.json
# BaltimoreMaryland.json
# BaltimoreMD.json
# BostonMassachusetts.json
# CharlotteNorth Carolina.json
# ChicagoIllinois.json
# ColumbusOhio.json
# DallasTexas.json
# DenverColorado.json
# DetroitMichigan.json
# El PasoTexas.json
# Fort WorthTexas.json
# HoustonTexas.json
# IndianapolisIndiana.json
# JacksonvilleFlorida.json
# Las VegasNevada.json
# Los AngelesCalifornia.json
# MemphisTennessee.json
# MilwaukeeWisconsin.json
# New YorkNew York.json
# Oklahoma CityOklahoma.json
# PhiladelphiaPennsylvania.json
# PortlandOregon.json
# San AntonioTexas.json
# San DiegoCalifornia.json
# San FranciscoCalifornia.json
# San JoseCalifornia.json
# SeattleWashington.json
# TucsonArizona.json
# WashingtonDistrict of Columbia.json

# %%
pred
# Out:
# [array([[ 10321116.57442655]]),
#  array([[ 3262653.32804952]]),
#  array([[ 28954070.66609702]]),
#  nan,
#  array([[ 10859565.39332839]]),
#  array([[ 6852724.8154342]]),
#  array([[ 5744698.13928173]]),
#  array([[ 10321116.57442655]]),
#  array([[ 10538197.73994985]]),
#  array([[ 6173059.48326146]]),
#  array([[ 12928935.35193463]]),
#  array([[ 2670777.69194861]]),
#  array([[ 10321116.57442655]]),
#  array([[ 12518166.71227856]]),
#  array([[ 18029301.50818853]]),
#  array([[ 10321116.57442655]]),
#  array([[ 9445232.1684626]]),
#  nan,
#  array([[ 10321116.57442655]]),
#  array([[ 3820660.38605036]]),
#  array([[ 10115572.0653574]]),
#  array([[ 10321116.57442655]]),
#  array([[ 4050871.69204421]]),
#  array([[ 13268914.04991783]]),
#  array([[ 10321116.57442655]]),
#  array([[ 9858341.80460609]])]

# %%
1e6
# Out:
# 1000000.0

# %%
def optimize_date_linear(date,TS,monthrange):
    dPR=datetime.strptime('2016-01-01', '%Y-%m-%d')
    monthmin=24
    dEN=dPR-relativedelta(months=monthmin)
    dST=dPR-relativedelta(months=monthmin+monthrange)
    #find indices of each date above
    
    
    try:
        idPR=next(id_ for id_, obj in enumerate(date) if obj>dPR)
        idEN=next(id_ for id_, obj in enumerate(date) if obj>dEN)
        idST=next(id_ for id_, obj in enumerate(date) if obj>dST)
        #convert to seconds
        datesec=[(item-datetime(1970,1,1)).total_seconds() for item in date]

        #find linear fit for dEN to dST
        regr = linear_model.LogisticRegression()
#         regr = linear_model.LinearRegression()
        
        #regr.fit_intercept = False
        x_train=np.array(datesec[idST:idEN]).reshape(-1,1)
        y_train=np.array(TS[idST:idEN])

#         y_train= y_train.reshape(y_train.size,1)
#         x_train=x_train.reshape(y_train.size,1)

        regr.fit(x_train, y_train)
    
        predicted=regr.predict(datesec[idPR])
        actual=np.mean(TS[idPR:])
#         r2=regr.score(x_train, y_train)
#     print('Variance score training set: %.2f' % regr.score(x_train, y_train))
    except:
        predicted=np.array([np.NAN])
        actual=np.array([np.NAN])
        coefs=np.array([np.NAN])
        r2=np.array([np.NAN])
#     print r2
#     print type(predicted[0]*1.0)
#     print type(actual)
#     print stop
    return np.array([predicted[0], actual])

# %%
plt.close('all')

months=range(6,49,3)
r2m=np.empty((len(filenames),len(months)))
for id_, filename in enumerate(filenames):
    print filename
    fig, ax=plt.subplots(nrows=1,ncols=1)
    
    with open('../../Data/Trulia/jsonfiles_wgeo/' + filename, 'r') as f:
        #open a city
        
        for jd_, monthrange in enumerate(months):
            predactu=np.empty((1,2))
            for kd_, line in enumerate(f):
                nowJSON=json.loads(line)
                medTS=np.array(nowJSON['medTS'])
                avgTS=np.array(nowJSON['avgTS'])
                date=[datetime.strptime(item, '%Y-%m-%d') for item in nowJSON['time']]
                pa=optimize_date_linear(date,avgTS,monthrange)
                predactu=np.concatenate((predactu,pa.reshape([1,-1])),axis=0)
                
            predactu=predactu[~np.isnan(predactu).any(axis=1)]
            r2m[id_,jd_]=pd.DataFrame(predactu).corr().get_value(0,1)
            f.seek(0)
        
        #plot accruacy of this city prediction versus month that I've searched    
#         ax.plot(months, r2m, linestyle='None', marker='.')
#         plt.show()
#     print stop
#             print stop
# Out:
# AlbuquerqueNew Mexico.json
# AustinTexas.json
# Balance of Los Angeles CountyCalifornia.json
# BaltimoreMaryland.json
# BaltimoreMD.json
# BostonMassachusetts.json
# CharlotteNorth Carolina.json
# ChicagoIllinois.json
# ColumbusOhio.json
# DallasTexas.json
# DenverColorado.json
# DetroitMichigan.json
# El PasoTexas.json
# Fort WorthTexas.json
# HoustonTexas.json
# IndianapolisIndiana.json
# JacksonvilleFlorida.json
# Las VegasNevada.json
# Los AngelesCalifornia.json
# MemphisTennessee.json
# MilwaukeeWisconsin.json
# /usr/local/lib/python2.7/site-packages/matplotlib/pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# New YorkNew York.json
# Oklahoma CityOklahoma.json
# PhiladelphiaPennsylvania.json
# ...

# %% [markdown]
# ### I have
# r2m will be the the ability for

# %%
plt.close('all')
print np.array(months).reshape(-1,1).shape
print np.array(r2m).T.shape
plt.plot(np.array(months).reshape(-1,1), np.array(r2m).T)

plt.show()
# Out:
# (15, 1)
# (15, 32)

# %%
with open('../../Data/Trulia/')
